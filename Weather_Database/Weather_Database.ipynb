# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


from citipy import citipy 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy 
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50 ):
        set_count += 1
        record_count = 1
      
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
     
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
     # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
 # Run an API request for each of the cities.
    try:
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    
 # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cayenne
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | la ronge
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | havelock
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | bandarbeyla
# Processing Record 12 of Set 1 | tougue
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | monrovia
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | guerrero negro
# Processing Record 21 of Set 1 | valley city
# Processing Record 22 of Set 1 | mandalgovi
# Processing Record 23 of Set 1 | yulara
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | naze
# Processing Record 29 of Set 1 | rabo de peixe
# Processing Record 30 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | ketchikan
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | san carlos de bariloche
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | kavaratti
# Processing Record 40 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 1 | salinas
# Processing Record 42 of Set 1 | havre-saint-pierre
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | moerai
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 1 | hami
# Processing Record 1 of Set 2 | cabra
# Processing Record 2 of Set 2 | araouane
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | kavieng
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | abalak
# Processing Record 8 of Set 2 | lagoa
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | kyshtovka
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | tshikapa
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | mayumba
# Processing Record 17 of Set 2 | pathein
# Processing Record 18 of Set 2 | sur
# Processing Record 19 of Set 2 | mweka
# Processing Record 20 of Set 2 | egvekinot
# Processing Record 21 of Set 2 | zhuhai
# Processing Record 22 of Set 2 | ngunguru
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | hasaki
# Processing Record 26 of Set 2 | ixtapa
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | manono
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | shimoda
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | svetlogorsk
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 2 | high prairie
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | namatanai
# Processing Record 40 of Set 2 | katangli
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | aplahoue
# Processing Record 43 of Set 2 | asau
# Processing Record 44 of Set 2 | tuatapere
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | shubarshi
# Processing Record 47 of Set 2 | grand-lahou
# Processing Record 48 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | taicheng
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | ciudad bolivar
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | morgan city
# Processing Record 8 of Set 3 | bandar-e lengeh
# Processing Record 9 of Set 3 | volchikha
# Processing Record 10 of Set 3 | rudbar
# Processing Record 11 of Set 3 | sakakah
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | north bend
# Processing Record 16 of Set 3 | blagoyevo
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | custodia
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | iskateley
# Processing Record 21 of Set 3 | vardo
# Processing Record 22 of Set 3 | batouri
# Processing Record 23 of Set 3 | pousat
# City not found. Skipping...
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | flinders
# Processing Record 26 of Set 3 | nikolayevsk-na-amure
# Processing Record 27 of Set 3 | ishigaki
# Processing Record 28 of Set 3 | taltal
# Processing Record 29 of Set 3 | veraval
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | prince rupert
# Processing Record 35 of Set 3 | ilhabela
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | hangu
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | coquimbo
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | bambous virieux
# Processing Record 42 of Set 3 | ayagoz
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | sumbawanga
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | brae
# Processing Record 47 of Set 3 | shelburne
# Processing Record 48 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 3 | nurota
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | rio pardo
# Processing Record 2 of Set 4 | khatanga
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | saint-joseph
# Processing Record 6 of Set 4 | matara
# Processing Record 7 of Set 4 | tulun
# Processing Record 8 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | nikolskoye
# Processing Record 10 of Set 4 | kempele
# Processing Record 11 of Set 4 | atar
# Processing Record 12 of Set 4 | chiredzi
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | rio gallegos
# Processing Record 15 of Set 4 | kendari
# Processing Record 16 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 4 | northam
# Processing Record 18 of Set 4 | belousovka
# Processing Record 19 of Set 4 | dalvik
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 4 | takoradi
# Processing Record 23 of Set 4 | russell
# Processing Record 24 of Set 4 | edd
# Processing Record 25 of Set 4 | grand-santi
# Processing Record 26 of Set 4 | santiago del estero
# Processing Record 27 of Set 4 | te anau
# Processing Record 28 of Set 4 | isangel
# Processing Record 29 of Set 4 | buraydah
# Processing Record 30 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | toba
# Processing Record 33 of Set 4 | opuwo
# Processing Record 34 of Set 4 | belmonte
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | eureka
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | rio grande
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | erzin
# Processing Record 43 of Set 4 | alta
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | suleja
# Processing Record 46 of Set 4 | sinnamary
# Processing Record 47 of Set 4 | puerto leguizamo
# Processing Record 48 of Set 4 | huangmei
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | atambua
# Processing Record 1 of Set 5 | rehoboth
# Processing Record 2 of Set 5 | tuktoyaktuk
# Processing Record 3 of Set 5 | kununurra
# Processing Record 4 of Set 5 | farmington
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | noumea
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | mtsensk
# Processing Record 9 of Set 5 | ecsed
# Processing Record 10 of Set 5 | merauke
# Processing Record 11 of Set 5 | huarmey
# Processing Record 12 of Set 5 | hambantota
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | half moon bay
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | srednekolymsk
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | karratha
# Processing Record 19 of Set 5 | freeport
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | praia da vitoria
# Processing Record 22 of Set 5 | port lincoln
# Processing Record 23 of Set 5 | klaksvik
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | seydisehir
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | harper
# Processing Record 28 of Set 5 | imeni karla libknekhta
# Processing Record 29 of Set 5 | kajaani
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | pekan
# Processing Record 33 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 5 | nishihara
# Processing Record 36 of Set 5 | tuxtla
# Processing Record 37 of Set 5 | narsaq
# Processing Record 38 of Set 5 | belize
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | campbellsville
# Processing Record 41 of Set 5 | sorong
# Processing Record 42 of Set 5 | cozumel
# Processing Record 43 of Set 5 | gladstone
# Processing Record 44 of Set 5 | ribeira grande
# Processing Record 45 of Set 5 | khani
# Processing Record 46 of Set 5 | vila
# Processing Record 47 of Set 5 | kargopol
# Processing Record 48 of Set 5 | pobe
# Processing Record 49 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 5 | deputatskiy
# Processing Record 1 of Set 6 | ingham
# Processing Record 2 of Set 6 | yarada
# Processing Record 3 of Set 6 | altay
# Processing Record 4 of Set 6 | purpe
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | limoeiro de anadia
# Processing Record 8 of Set 6 | tshane
# Processing Record 9 of Set 6 | kasongo-lunda
# Processing Record 10 of Set 6 | micheweni
# Processing Record 11 of Set 6 | oktyabrskiy
# Processing Record 12 of Set 6 | arklow
# Processing Record 13 of Set 6 | pinyug
# Processing Record 14 of Set 6 | nagua
# Processing Record 15 of Set 6 | sampit
# Processing Record 16 of Set 6 | ayr
# Processing Record 17 of Set 6 | navahrudak
# Processing Record 18 of Set 6 | inhambane
# Processing Record 19 of Set 6 | grafton
# Processing Record 20 of Set 6 | tilichiki
# Processing Record 21 of Set 6 | upata
# Processing Record 22 of Set 6 | nizwa
# Processing Record 23 of Set 6 | maltahohe
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | bac lieu
# Processing Record 26 of Set 6 | cabedelo
# Processing Record 27 of Set 6 | tual
# Processing Record 28 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 6 | cusuna
# Processing Record 30 of Set 6 | lamu
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | itoman
# Processing Record 33 of Set 6 | bengkulu
# Processing Record 34 of Set 6 | novaya bryan
# Processing Record 35 of Set 6 | longyan
# Processing Record 36 of Set 6 | gayeri
# Processing Record 37 of Set 6 | champerico
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | ozinki
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | san ignacio
# Processing Record 42 of Set 6 | iskitim
# Processing Record 43 of Set 6 | whitehorse
# Processing Record 44 of Set 6 | san pedro de macoris
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | sretensk
# Processing Record 47 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 6 | saint-francois
# Processing Record 49 of Set 6 | tura
# Processing Record 50 of Set 6 | avera
# Processing Record 1 of Set 7 | aklavik
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | nantucket
# Processing Record 4 of Set 7 | abu dhabi
# Processing Record 5 of Set 7 | sept-iles
# Processing Record 6 of Set 7 | denpasar
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | malangali
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | nouadhibou
# Processing Record 11 of Set 7 | banswara
# Processing Record 12 of Set 7 | along
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | komsomolskiy
# Processing Record 15 of Set 7 | ponta delgada
# Processing Record 16 of Set 7 | nabire
# Processing Record 17 of Set 7 | baghdad
# Processing Record 18 of Set 7 | boden
# Processing Record 19 of Set 7 | toora-khem
# Processing Record 20 of Set 7 | nuuk
# Processing Record 21 of Set 7 | goderich
# Processing Record 22 of Set 7 | labuhan
# Processing Record 23 of Set 7 | chapais
# Processing Record 24 of Set 7 | taoudenni
# Processing Record 25 of Set 7 | minab
# Processing Record 26 of Set 7 | kamenka
# Processing Record 27 of Set 7 | ulaangom
# Processing Record 28 of Set 7 | bonavista
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | oranjestad
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | gamba
# Processing Record 33 of Set 7 | xunchang
# Processing Record 34 of Set 7 | hof
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | souillac
# Processing Record 37 of Set 7 | surt
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | sudislavl
# Processing Record 40 of Set 7 | alubijid
# Processing Record 41 of Set 7 | qandala
# Processing Record 42 of Set 7 | sabha
# Processing Record 43 of Set 7 | wamba
# Processing Record 44 of Set 7 | tara
# Processing Record 45 of Set 7 | guimar
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | mbandaka
# Processing Record 48 of Set 7 | korla
# Processing Record 49 of Set 7 | otradnoye
# Processing Record 50 of Set 7 | tumbi
# Processing Record 1 of Set 8 | casper
# Processing Record 2 of Set 8 | sao joao da barra
# Processing Record 3 of Set 8 | bata
# Processing Record 4 of Set 8 | bathsheba
# Processing Record 5 of Set 8 | sao jose da coroa grande
# Processing Record 6 of Set 8 | college
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 8 | saint-augustin
# Processing Record 9 of Set 8 | ust-nera
# Processing Record 10 of Set 8 | bontang
# Processing Record 11 of Set 8 | chernyshevskiy
# Processing Record 12 of Set 8 | verkhnevilyuysk
# Processing Record 13 of Set 8 | sorland
# Processing Record 14 of Set 8 | monte cristi
# City not found. Skipping...
# Processing Record 15 of Set 8 | conde
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | khasan
# Processing Record 18 of Set 8 | port elizabeth
# Processing Record 19 of Set 8 | saint stephen
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | koubia
# Processing Record 22 of Set 8 | chapelton
# Processing Record 23 of Set 8 | nha trang
# Processing Record 24 of Set 8 | bay city
# Processing Record 25 of Set 8 | mitu
# Processing Record 26 of Set 8 | comarapa
# Processing Record 27 of Set 8 | nanortalik
# Processing Record 28 of Set 8 | ormara
# Processing Record 29 of Set 8 | xuanzhou
# Processing Record 30 of Set 8 | ajdabiya
# Processing Record 31 of Set 8 | hede
# Processing Record 32 of Set 8 | akdepe
# Processing Record 33 of Set 8 | sereflikochisar
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | ihosy
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | smirnykh
# Processing Record 38 of Set 8 | lazaro cardenas
# Processing Record 39 of Set 8 | taungdwingyi
# Processing Record 40 of Set 8 | amga
# Processing Record 41 of Set 8 | sakyla
# Processing Record 42 of Set 8 | kungsbacka
# Processing Record 43 of Set 8 | juneau
# Processing Record 44 of Set 8 | manta
# Processing Record 45 of Set 8 | agirish
# Processing Record 46 of Set 8 | ribeira brava
# Processing Record 47 of Set 8 | stefanesti
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | lasa
# Processing Record 50 of Set 8 | muros
# Processing Record 1 of Set 9 | swan river
# Processing Record 2 of Set 9 | malpe
# Processing Record 3 of Set 9 | mumford
# Processing Record 4 of Set 9 | port augusta
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | visby
# Processing Record 7 of Set 9 | castro
# Processing Record 8 of Set 9 | rumonge
# Processing Record 9 of Set 9 | storsteinnes
# Processing Record 10 of Set 9 | port blair
# Processing Record 11 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 9 | port moresby
# Processing Record 14 of Set 9 | ust-uda
# Processing Record 15 of Set 9 | teya
# Processing Record 16 of Set 9 | saldanha
# Processing Record 17 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 9 | waingapu
# Processing Record 19 of Set 9 | villa carlos paz
# Processing Record 20 of Set 9 | brooks
# Processing Record 21 of Set 9 | myitkyina
# Processing Record 22 of Set 9 | poum
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | port hardy
# Processing Record 25 of Set 9 | vilyuysk
# Processing Record 26 of Set 9 | mackay
# Processing Record 27 of Set 9 | tete
# Processing Record 28 of Set 9 | kiama
# Processing Record 29 of Set 9 | jiazi
# Processing Record 30 of Set 9 | selikhino
# Processing Record 31 of Set 9 | karpogory
# Processing Record 32 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | azangaro
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | diu
# Processing Record 37 of Set 9 | sangar
# Processing Record 38 of Set 9 | bairnsdale
# Processing Record 39 of Set 9 | tabou
# Processing Record 40 of Set 9 | heze
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | lethem
# Processing Record 43 of Set 9 | yakima
# Processing Record 44 of Set 9 | vila franca do campo
# Processing Record 45 of Set 9 | miri
# Processing Record 46 of Set 9 | porto novo
# Processing Record 47 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 9 | daru
# Processing Record 49 of Set 9 | lodja
# Processing Record 50 of Set 9 | menongue
# Processing Record 1 of Set 10 | ossora
# Processing Record 2 of Set 10 | mareeba
# Processing Record 3 of Set 10 | kaeo
# Processing Record 4 of Set 10 | panaba
# Processing Record 5 of Set 10 | talaya
# Processing Record 6 of Set 10 | rockland
# Processing Record 7 of Set 10 | charters towers
# Processing Record 8 of Set 10 | cidreira
# Processing Record 9 of Set 10 | langham
# Processing Record 10 of Set 10 | paragould
# Processing Record 11 of Set 10 | luganville
# Processing Record 12 of Set 10 | japura
# Processing Record 13 of Set 10 | okato
# Processing Record 14 of Set 10 | baykit
# Processing Record 15 of Set 10 | madison
# Processing Record 16 of Set 10 | minden
# Processing Record 17 of Set 10 | vaitape
# Processing Record 18 of Set 10 | kombotion
# City not found. Skipping...
# Processing Record 19 of Set 10 | tessalit
# Processing Record 20 of Set 10 | omboue
# Processing Record 21 of Set 10 | gombong
# Processing Record 22 of Set 10 | san andres
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | yar-sale
# Processing Record 25 of Set 10 | graaff-reinet
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | warrnambool
# Processing Record 28 of Set 10 | sioux lookout
# Processing Record 29 of Set 10 | hundested
# Processing Record 30 of Set 10 | cockburn town
# Processing Record 31 of Set 10 | canmore
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | pasni
# Processing Record 35 of Set 10 | mahibadhoo
# Processing Record 36 of Set 10 | fort nelson
# Processing Record 37 of Set 10 | porto de moz
# Processing Record 38 of Set 10 | mattru
# Processing Record 39 of Set 10 | tevaitoa
# Processing Record 40 of Set 10 | laguna
# Processing Record 41 of Set 10 | byron bay
# Processing Record 42 of Set 10 | peringat
# Processing Record 43 of Set 10 | elk city
# Processing Record 44 of Set 10 | ratangarh
# Processing Record 45 of Set 10 | buluang
# Processing Record 46 of Set 10 | cao bang
# Processing Record 47 of Set 10 | codrington
# Processing Record 48 of Set 10 | mixquiahuala
# Processing Record 49 of Set 10 | paamiut
# Processing Record 50 of Set 10 | hollola
# Processing Record 1 of Set 11 | melville
# Processing Record 2 of Set 11 | boa vista
# Processing Record 3 of Set 11 | waipawa
# Processing Record 4 of Set 11 | acari
# Processing Record 5 of Set 11 | saint johnsbury
# Processing Record 6 of Set 11 | gat
# Processing Record 7 of Set 11 | bereda
# Processing Record 8 of Set 11 | solnechnyy
# Processing Record 9 of Set 11 | puerto colombia
# Processing Record 10 of Set 11 | esmeraldas
# Processing Record 11 of Set 11 | methoni
# Processing Record 12 of Set 11 | esperance
# Processing Record 13 of Set 11 | lander
# Processing Record 14 of Set 11 | gizo
# Processing Record 15 of Set 11 | pangoa
# Processing Record 16 of Set 11 | tolaga bay
# Processing Record 17 of Set 11 | pareora
# Processing Record 18 of Set 11 | farah
# Processing Record 19 of Set 11 | koulikoro
# Processing Record 20 of Set 11 | ambilobe
# Processing Record 21 of Set 11 | amalapuram
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | bagdarin
# Processing Record 24 of Set 11 | roros
# Processing Record 25 of Set 11 | beyneu
# Processing Record 26 of Set 11 | scarborough
# Processing Record 27 of Set 11 | apaseo el grande
# Processing Record 28 of Set 11 | korcula
# Processing Record 29 of Set 11 | bairiki
# Processing Record 30 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 11 | saint-pierre
# Processing Record 32 of Set 11 | woodward
# Processing Record 33 of Set 11 | aden
# Processing Record 34 of Set 11 | salamanca
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 11 | kings point
# Processing Record 38 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 11 | pemba
# Processing Record 40 of Set 11 | havoysund
# Processing Record 41 of Set 11 | manuk mangkaw
# Processing Record 42 of Set 11 | ormstown
# Processing Record 43 of Set 11 | parakai
# Processing Record 44 of Set 11 | khao yoi
# Processing Record 45 of Set 11 | orel
# Processing Record 46 of Set 11 | burnie
# Processing Record 47 of Set 11 | kaya
# Processing Record 48 of Set 11 | okhotsk
# Processing Record 49 of Set 11 | kirakira
# Processing Record 50 of Set 11 | mayo
# Processing Record 1 of Set 12 | meulaboh
# Processing Record 2 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 12 | yatou
# Processing Record 4 of Set 12 | tautira
# Processing Record 5 of Set 12 | taga dzong
# City not found. Skipping...
# Processing Record 6 of Set 12 | bousse
# Processing Record 7 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 12 | yeppoon
# Processing Record 9 of Set 12 | kerema
# Processing Record 10 of Set 12 | bologoye
# Processing Record 11 of Set 12 | mirabad
# Processing Record 12 of Set 12 | diamantino
# Processing Record 13 of Set 12 | nakamura
# Processing Record 14 of Set 12 | balkhash
# Processing Record 15 of Set 12 | ananas
# Processing Record 16 of Set 12 | richards bay
# Processing Record 17 of Set 12 | andenes
# Processing Record 18 of Set 12 | aksu
# Processing Record 19 of Set 12 | kelowna
# Processing Record 20 of Set 12 | coffs harbour
# Processing Record 21 of Set 12 | ekibastuz
# Processing Record 22 of Set 12 | altamirano
# Processing Record 23 of Set 12 | gilbues
# Processing Record 24 of Set 12 | vung tau
# Processing Record 25 of Set 12 | mucurapo
# Processing Record 26 of Set 12 | klamath falls
# Processing Record 27 of Set 12 | pirgos
# Processing Record 28 of Set 12 | mezhdurechensk
# Processing Record 29 of Set 12 | lanigan
# Processing Record 30 of Set 12 | nelson
# Processing Record 31 of Set 12 | beian
# Processing Record 32 of Set 12 | urumqi
# Processing Record 33 of Set 12 | bahia blanca
# Processing Record 34 of Set 12 | sandwick
# Processing Record 35 of Set 12 | brainerd
# Processing Record 36 of Set 12 | kjopsvik
# Processing Record 37 of Set 12 | santo domingo
# Processing Record 38 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 12 | chudniv
# Processing Record 41 of Set 12 | tezu
# Processing Record 42 of Set 12 | cairns
# Processing Record 43 of Set 12 | skjervoy
# Processing Record 44 of Set 12 | pangkalanbuun
# Processing Record 45 of Set 12 | winnemucca
# Processing Record 46 of Set 12 | hofn
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | port hedland
# Processing Record 49 of Set 12 | kupang
# Processing Record 50 of Set 12 | terrace bay
# Processing Record 1 of Set 13 | anito
# Processing Record 2 of Set 13 | nogliki
# Processing Record 3 of Set 13 | kirensk
# Processing Record 4 of Set 13 | kieta
# Processing Record 5 of Set 13 | natal
# Processing Record 6 of Set 13 | pangnirtung
# Processing Record 7 of Set 13 | san vicente
# Processing Record 8 of Set 13 | suzuka
# Processing Record 9 of Set 13 | vlasim
# Processing Record 10 of Set 13 | novospasskoye
# Processing Record 11 of Set 13 | tsabong
# Processing Record 12 of Set 13 | carrboro
# Processing Record 13 of Set 13 | pucallpa
# Processing Record 14 of Set 13 | conneaut
# Processing Record 15 of Set 13 | genhe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Cayenne   4.9333  -52.3333     79.09         1          75        5.99
# 1      Mataura -46.1927  168.8643     49.60        81          66       12.86
# 2     La Ronge  55.1001 -105.2842     46.65        39          20       11.50
# 3       Bethel  41.3712  -73.4140     50.40        57          98        1.01
# 4      Rikitea -23.1203 -134.9692     78.66        68          43       17.65
# 5        Sitka  57.0531 -135.3300     44.49        61          75       11.50
# 6     Havelock  34.8791  -76.9013     70.02        82          75        9.22
# 7      Ushuaia -54.8000  -68.3000     37.06        87          40       25.32
# 8  Yellowknife  62.4560 -114.3525     31.41        74         100       10.36
# 9  New Norfolk -42.7826  147.0587     57.65        44          31        2.66
#
#   Country      Current Description                 Date
# 0      GF            broken clouds  2022-04-05 23:51:04
# 1      NZ            broken clouds  2022-04-05 23:51:04
# 2      CA               few clouds  2022-04-05 23:51:04
# 3      US          overcast clouds  2022-04-05 23:51:05
# 4      PF         scattered clouds  2022-04-05 23:51:01
# 5      US            broken clouds  2022-04-05 23:51:05
# 6      US            broken clouds  2022-04-05 23:51:06
# 7      AR  light intensity drizzle  2022-04-05 23:49:14
# 8      CA          overcast clouds  2022-04-05 23:51:06
# 9      AU         scattered clouds  2022-04-05 23:51:06

# %%
# Correct the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cayenne      GF   4.9333  -52.3333     79.09         1          75
# 1      Mataura      NZ -46.1927  168.8643     49.60        81          66
# 2     La Ronge      CA  55.1001 -105.2842     46.65        39          20
# 3       Bethel      US  41.3712  -73.4140     50.40        57          98
# 4      Rikitea      PF -23.1203 -134.9692     78.66        68          43
# 5        Sitka      US  57.0531 -135.3300     44.49        61          75
# 6     Havelock      US  34.8791  -76.9013     70.02        82          75
# 7      Ushuaia      AR -54.8000  -68.3000     37.06        87          40
# 8  Yellowknife      CA  62.4560 -114.3525     31.41        74         100
# 9  New Norfolk      AU -42.7826  147.0587     57.65        44          31
#
#    Wind Speed      Current Description                 Date
# 0        5.99            broken clouds  2022-04-05 23:51:04
# 1       12.86            broken clouds  2022-04-05 23:51:04
# 2       11.50               few clouds  2022-04-05 23:51:04
# 3        1.01          overcast clouds  2022-04-05 23:51:05
# 4       17.65         scattered clouds  2022-04-05 23:51:01
# 5       11.50            broken clouds  2022-04-05 23:51:05
# 6        9.22            broken clouds  2022-04-05 23:51:06
# 7       25.32  light intensity drizzle  2022-04-05 23:49:14
# 8       10.36          overcast clouds  2022-04-05 23:51:06
# 9        2.66         scattered clouds  2022-04-05 23:51:06

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

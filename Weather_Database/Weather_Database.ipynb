# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


from citipy import citipy 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy 
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50 ):
        set_count += 1
        record_count = 1
      
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
     
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
     # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
 # Run an API request for each of the cities.
    try:
    
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    
 # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tilzapotla
# Processing Record 2 of Set 1 | luderitz
# Processing Record 3 of Set 1 | chumikan
# Processing Record 4 of Set 1 | pacific grove
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | qasigiannguit
# Processing Record 8 of Set 1 | weyburn
# Processing Record 9 of Set 1 | cap-aux-meules
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | greensburg
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | puerto escondido
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | tshikapa
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | show low
# Processing Record 23 of Set 1 | malanje
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | durango
# Processing Record 26 of Set 1 | saint-augustin
# Processing Record 27 of Set 1 | phayao
# Processing Record 28 of Set 1 | souillac
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | westport
# Processing Record 31 of Set 1 | bahia de caraquez
# Processing Record 32 of Set 1 | omsukchan
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | punta cardon
# Processing Record 35 of Set 1 | jurmala
# Processing Record 36 of Set 1 | krasnomayskiy
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | tiarei
# Processing Record 39 of Set 1 | joao pinheiro
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | hami
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | pemberton
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | dingle
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | srednekolymsk
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | daru
# Processing Record 2 of Set 2 | mollendo
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | vardo
# Processing Record 5 of Set 2 | wajir
# Processing Record 6 of Set 2 | labuhan
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | grand gaube
# Processing Record 9 of Set 2 | burnie
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | davenport
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | salalah
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | opuwo
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | zhelyabovka
# Processing Record 19 of Set 2 | lincoln
# Processing Record 20 of Set 2 | axim
# Processing Record 21 of Set 2 | raton
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | flinders
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | manggar
# Processing Record 33 of Set 2 | zhigansk
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 2 | lucapa
# Processing Record 40 of Set 2 | ipubi
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | port moresby
# Processing Record 43 of Set 2 | san nicolas
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | brigantine
# Processing Record 2 of Set 3 | dakar
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | asyut
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | nelson bay
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | nome
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | paciran
# Processing Record 14 of Set 3 | alice springs
# Processing Record 15 of Set 3 | celestun
# Processing Record 16 of Set 3 | progreso
# Processing Record 17 of Set 3 | sao jose da coroa grande
# Processing Record 18 of Set 3 | neiafu
# Processing Record 19 of Set 3 | payo
# Processing Record 20 of Set 3 | namatanai
# Processing Record 21 of Set 3 | fallon
# Processing Record 22 of Set 3 | maceio
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | marivan
# Processing Record 25 of Set 3 | pochutla
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | tsiroanomandidy
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | portobelo
# Processing Record 30 of Set 3 | beian
# Processing Record 31 of Set 3 | mataura
# Processing Record 32 of Set 3 | tomatlan
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | chancay
# Processing Record 35 of Set 3 | praia
# Processing Record 36 of Set 3 | azare
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | peniche
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | duz
# City not found. Skipping...
# Processing Record 43 of Set 3 | puerto carreno
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | zabid
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | mehamn
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | kuopio
# Processing Record 50 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 4 | portland
# Processing Record 2 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 4 | la rioja
# Processing Record 4 of Set 4 | concarneau
# Processing Record 5 of Set 4 | bilma
# Processing Record 6 of Set 4 | cambrai
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | goundam
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | zelenoborskiy
# Processing Record 11 of Set 4 | richha
# Processing Record 12 of Set 4 | shepsi
# Processing Record 13 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 4 | vaini
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | mushie
# Processing Record 17 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 4 | selma
# Processing Record 19 of Set 4 | innisfail
# Processing Record 20 of Set 4 | bonavista
# Processing Record 21 of Set 4 | manta
# Processing Record 22 of Set 4 | buraydah
# Processing Record 23 of Set 4 | can
# Processing Record 24 of Set 4 | husavik
# Processing Record 25 of Set 4 | coxim
# Processing Record 26 of Set 4 | ratnagiri
# Processing Record 27 of Set 4 | roald
# Processing Record 28 of Set 4 | bilibino
# Processing Record 29 of Set 4 | salym
# Processing Record 30 of Set 4 | le vauclin
# Processing Record 31 of Set 4 | kenai
# Processing Record 32 of Set 4 | cape town
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 4 | maua
# Processing Record 36 of Set 4 | xai-xai
# Processing Record 37 of Set 4 | darhan
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | thinadhoo
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | muroto
# Processing Record 42 of Set 4 | baykit
# Processing Record 43 of Set 4 | ginda
# Processing Record 44 of Set 4 | brooks
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | businga
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | baculin
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | arkul
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | kassala
# Processing Record 6 of Set 5 | charters towers
# Processing Record 7 of Set 5 | vestmanna
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | ixtapa
# Processing Record 10 of Set 5 | vestmannaeyjar
# Processing Record 11 of Set 5 | korhogo
# Processing Record 12 of Set 5 | veraval
# Processing Record 13 of Set 5 | kokkola
# Processing Record 14 of Set 5 | prince rupert
# Processing Record 15 of Set 5 | oda
# Processing Record 16 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 5 | pio xii
# Processing Record 18 of Set 5 | natchez
# Processing Record 19 of Set 5 | severo-kurilsk
# Processing Record 20 of Set 5 | olafsvik
# Processing Record 21 of Set 5 | itarema
# Processing Record 22 of Set 5 | kaitangata
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | agua verde
# Processing Record 25 of Set 5 | dzaoudzi
# Processing Record 26 of Set 5 | boguchany
# Processing Record 27 of Set 5 | camacupa
# Processing Record 28 of Set 5 | ballina
# Processing Record 29 of Set 5 | ulaanbaatar
# Processing Record 30 of Set 5 | bon air
# Processing Record 31 of Set 5 | okhotsk
# Processing Record 32 of Set 5 | butaritari
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | stromness
# Processing Record 35 of Set 5 | serik
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | iquique
# Processing Record 38 of Set 5 | mayor pablo lagerenza
# Processing Record 39 of Set 5 | noumea
# Processing Record 40 of Set 5 | fuling
# Processing Record 41 of Set 5 | dombarovskiy
# Processing Record 42 of Set 5 | dunedin
# Processing Record 43 of Set 5 | hervey bay
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | bay roberts
# Processing Record 47 of Set 5 | villa carlos paz
# Processing Record 48 of Set 5 | mitsamiouli
# Processing Record 49 of Set 5 | college
# Processing Record 50 of Set 5 | angoche
# Processing Record 1 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 6 | buba
# Processing Record 3 of Set 6 | gogrial
# Processing Record 4 of Set 6 | mazamari
# Processing Record 5 of Set 6 | nador
# Processing Record 6 of Set 6 | poronaysk
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | bowen
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | nemuro
# Processing Record 11 of Set 6 | pushkino
# Processing Record 12 of Set 6 | kloulklubed
# Processing Record 13 of Set 6 | sinnamary
# Processing Record 14 of Set 6 | tuktoyaktuk
# Processing Record 15 of Set 6 | coffeyville
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | eirunepe
# Processing Record 18 of Set 6 | parry sound
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | siuna
# Processing Record 21 of Set 6 | lata
# Processing Record 22 of Set 6 | saskylakh
# Processing Record 23 of Set 6 | camana
# Processing Record 24 of Set 6 | huarmey
# Processing Record 25 of Set 6 | hermanus
# Processing Record 26 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 6 | palmer
# Processing Record 28 of Set 6 | igarka
# Processing Record 29 of Set 6 | tuatapere
# Processing Record 30 of Set 6 | lamar
# Processing Record 31 of Set 6 | bonfim
# Processing Record 32 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | carlyle
# Processing Record 35 of Set 6 | fairbanks
# Processing Record 36 of Set 6 | ambilobe
# Processing Record 37 of Set 6 | provost
# Processing Record 38 of Set 6 | tautira
# Processing Record 39 of Set 6 | powassan
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | galle
# Processing Record 42 of Set 6 | reconquista
# Processing Record 43 of Set 6 | eyl
# Processing Record 44 of Set 6 | chokurdakh
# Processing Record 45 of Set 6 | cidreira
# Processing Record 46 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 6 | gwadar
# Processing Record 48 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 6 | camargo
# Processing Record 50 of Set 6 | wanning
# Processing Record 1 of Set 7 | bandraboua
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | madras
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | verkhoshizhemye
# Processing Record 6 of Set 7 | mujiayingzi
# Processing Record 7 of Set 7 | mosquera
# Processing Record 8 of Set 7 | launceston
# Processing Record 9 of Set 7 | kurumkan
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | mastic beach
# Processing Record 12 of Set 7 | yumen
# Processing Record 13 of Set 7 | sioux lookout
# Processing Record 14 of Set 7 | randfontein
# Processing Record 15 of Set 7 | murray
# Processing Record 16 of Set 7 | thompson
# Processing Record 17 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 7 | kannad
# Processing Record 19 of Set 7 | domanivka
# Processing Record 20 of Set 7 | sobolevo
# Processing Record 21 of Set 7 | san ramon
# Processing Record 22 of Set 7 | bathsheba
# Processing Record 23 of Set 7 | traverse city
# Processing Record 24 of Set 7 | goderich
# Processing Record 25 of Set 7 | kadoma
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | bukachacha
# Processing Record 28 of Set 7 | ossora
# Processing Record 29 of Set 7 | tura
# Processing Record 30 of Set 7 | aguimes
# Processing Record 31 of Set 7 | parczew
# Processing Record 32 of Set 7 | starobaltachevo
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | vrangel
# Processing Record 35 of Set 7 | datong
# Processing Record 36 of Set 7 | waddan
# Processing Record 37 of Set 7 | hamilton
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | berlevag
# Processing Record 40 of Set 7 | bambous virieux
# Processing Record 41 of Set 7 | khandyga
# Processing Record 42 of Set 7 | leh
# Processing Record 43 of Set 7 | sakaraha
# Processing Record 44 of Set 7 | pimenta bueno
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | salta
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | nhulunbuy
# Processing Record 50 of Set 7 | gurupa
# Processing Record 1 of Set 8 | bitung
# Processing Record 2 of Set 8 | mar del plata
# Processing Record 3 of Set 8 | boca do acre
# Processing Record 4 of Set 8 | guadalajara
# Processing Record 5 of Set 8 | andros town
# Processing Record 6 of Set 8 | luba
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | jacmel
# Processing Record 9 of Set 8 | gat
# Processing Record 10 of Set 8 | ville-marie
# Processing Record 11 of Set 8 | samarai
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | george town
# Processing Record 14 of Set 8 | sao filipe
# Processing Record 15 of Set 8 | jalu
# Processing Record 16 of Set 8 | meadow lake
# Processing Record 17 of Set 8 | okhtyrka
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | svetlogorsk
# Processing Record 20 of Set 8 | areka
# Processing Record 21 of Set 8 | townsville
# Processing Record 22 of Set 8 | nioaque
# Processing Record 23 of Set 8 | vallenar
# Processing Record 24 of Set 8 | lahat
# Processing Record 25 of Set 8 | patiya
# Processing Record 26 of Set 8 | sikonge
# Processing Record 27 of Set 8 | ajaccio
# Processing Record 28 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 8 | valleyview
# Processing Record 30 of Set 8 | jimenez
# Processing Record 31 of Set 8 | kimberley
# Processing Record 32 of Set 8 | taoudenni
# Processing Record 33 of Set 8 | tam ky
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | montepuez
# Processing Record 36 of Set 8 | hovd
# Processing Record 37 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 8 | dilla
# Processing Record 39 of Set 8 | dongsheng
# Processing Record 40 of Set 8 | aklavik
# Processing Record 41 of Set 8 | saint anthony
# Processing Record 42 of Set 8 | vilyuysk
# Processing Record 43 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 8 | marystown
# Processing Record 45 of Set 8 | rawlins
# Processing Record 46 of Set 8 | ziro
# Processing Record 47 of Set 8 | sola
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | port blair
# Processing Record 50 of Set 8 | methoni
# Processing Record 1 of Set 9 | brandon
# Processing Record 2 of Set 9 | kjollefjord
# Processing Record 3 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 4 of Set 9 | kushiro
# Processing Record 5 of Set 9 | gornopravdinsk
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 9 | graham
# Processing Record 9 of Set 9 | lavrentiya
# Processing Record 10 of Set 9 | gizo
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | santa vitoria do palmar
# Processing Record 13 of Set 9 | kristiansund
# Processing Record 14 of Set 9 | solnechnyy
# Processing Record 15 of Set 9 | matara
# Processing Record 16 of Set 9 | mo i rana
# Processing Record 17 of Set 9 | manadhoo
# Processing Record 18 of Set 9 | maningrida
# Processing Record 19 of Set 9 | pouebo
# Processing Record 20 of Set 9 | lujan
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | sao miguel do araguaia
# Processing Record 23 of Set 9 | waingapu
# Processing Record 24 of Set 9 | varkaus
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 9 | sisian
# Processing Record 28 of Set 9 | valley city
# Processing Record 29 of Set 9 | anadyr
# Processing Record 30 of Set 9 | champerico
# Processing Record 31 of Set 9 | namibe
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | karaton
# Processing Record 34 of Set 9 | gamba
# Processing Record 35 of Set 9 | muswellbrook
# Processing Record 36 of Set 9 | jimma
# Processing Record 37 of Set 9 | roma
# Processing Record 38 of Set 9 | kautokeino
# Processing Record 39 of Set 9 | puerto varas
# Processing Record 40 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 9 | pirai do sul
# Processing Record 42 of Set 9 | ihlow
# Processing Record 43 of Set 9 | phonhong
# Processing Record 44 of Set 9 | nizwa
# Processing Record 45 of Set 9 | ribeira brava
# Processing Record 46 of Set 9 | novikovo
# Processing Record 47 of Set 9 | macamic
# Processing Record 48 of Set 9 | alofi
# Processing Record 49 of Set 9 | summerville
# Processing Record 50 of Set 9 | klaksvik
# Processing Record 1 of Set 10 | zyryanka
# Processing Record 2 of Set 10 | juan lacaze
# Processing Record 3 of Set 10 | jumla
# Processing Record 4 of Set 10 | houma
# Processing Record 5 of Set 10 | turukhansk
# Processing Record 6 of Set 10 | high rock
# Processing Record 7 of Set 10 | touros
# Processing Record 8 of Set 10 | dubbo
# Processing Record 9 of Set 10 | nakamura
# Processing Record 10 of Set 10 | rimbey
# Processing Record 11 of Set 10 | tabou
# Processing Record 12 of Set 10 | chuy
# Processing Record 13 of Set 10 | leningradskiy
# Processing Record 14 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 10 | seoul
# Processing Record 16 of Set 10 | yegorlykskaya
# Processing Record 17 of Set 10 | gallup
# Processing Record 18 of Set 10 | namtsy
# Processing Record 19 of Set 10 | tahe
# Processing Record 20 of Set 10 | lukovetskiy
# Processing Record 21 of Set 10 | guilin
# Processing Record 22 of Set 10 | gander
# Processing Record 23 of Set 10 | north platte
# Processing Record 24 of Set 10 | boden
# Processing Record 25 of Set 10 | naron
# Processing Record 26 of Set 10 | havelock
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | mitu
# Processing Record 29 of Set 10 | outlook
# Processing Record 30 of Set 10 | tamiahua
# Processing Record 31 of Set 10 | bac lieu
# Processing Record 32 of Set 10 | lensk
# Processing Record 33 of Set 10 | vao
# Processing Record 34 of Set 10 | ulfborg
# Processing Record 35 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | dawei
# Processing Record 38 of Set 10 | clarence town
# Processing Record 39 of Set 10 | tual
# Processing Record 40 of Set 10 | lungi
# Processing Record 41 of Set 10 | grindavik
# Processing Record 42 of Set 10 | najran
# Processing Record 43 of Set 10 | luancheng
# Processing Record 44 of Set 10 | general roca
# Processing Record 45 of Set 10 | lerwick
# Processing Record 46 of Set 10 | keti bandar
# Processing Record 47 of Set 10 | yeppoon
# Processing Record 48 of Set 10 | balakhninskiy
# Processing Record 49 of Set 10 | almora
# Processing Record 50 of Set 10 | arraial do cabo
# Processing Record 1 of Set 11 | manono
# Processing Record 2 of Set 11 | nouadhibou
# Processing Record 3 of Set 11 | rio gallegos
# Processing Record 4 of Set 11 | maniitsoq
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 11 | kieta
# Processing Record 8 of Set 11 | lorengau
# Processing Record 9 of Set 11 | coquimbo
# Processing Record 10 of Set 11 | markova
# Processing Record 11 of Set 11 | sur
# Processing Record 12 of Set 11 | takoradi
# Processing Record 13 of Set 11 | san quintin
# Processing Record 14 of Set 11 | lompoc
# Processing Record 15 of Set 11 | sorong
# Processing Record 16 of Set 11 | dharchula
# Processing Record 17 of Set 11 | guanambi
# Processing Record 18 of Set 11 | sicamous
# Processing Record 19 of Set 11 | malakal
# Processing Record 20 of Set 11 | khuzhir
# Processing Record 21 of Set 11 | manga
# Processing Record 22 of Set 11 | saint-francois
# Processing Record 23 of Set 11 | guerrero negro
# Processing Record 24 of Set 11 | caravelas
# Processing Record 25 of Set 11 | vaasa
# Processing Record 26 of Set 11 | the pas
# Processing Record 27 of Set 11 | kushikino
# Processing Record 28 of Set 11 | wufeng
# Processing Record 29 of Set 11 | brae
# Processing Record 30 of Set 11 | kisangani
# Processing Record 31 of Set 11 | asau
# Processing Record 32 of Set 11 | ancud
# Processing Record 33 of Set 11 | zhangye
# Processing Record 34 of Set 11 | alakurtti
# Processing Record 35 of Set 11 | bairiki
# Processing Record 36 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 11 | coahuayana
# Processing Record 38 of Set 11 | korem
# Processing Record 39 of Set 11 | yerbogachen
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | tazovskiy
# Processing Record 42 of Set 11 | bol
# Processing Record 43 of Set 11 | tongliao
# Processing Record 44 of Set 11 | ati
# Processing Record 45 of Set 11 | palu
# Processing Record 46 of Set 11 | balkanabat
# Processing Record 47 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 49 of Set 11 | beroroha
# Processing Record 50 of Set 11 | terrace bay
# Processing Record 1 of Set 12 | dungarvan
# Processing Record 2 of Set 12 | iraquara
# Processing Record 3 of Set 12 | port hawkesbury
# Processing Record 4 of Set 12 | warrnambool
# Processing Record 5 of Set 12 | povenets
# Processing Record 6 of Set 12 | maridi
# Processing Record 7 of Set 12 | luziania
# Processing Record 8 of Set 12 | clinton
# Processing Record 9 of Set 12 | kiama
# Processing Record 10 of Set 12 | sarangani
# Processing Record 11 of Set 12 | garowe
# Processing Record 12 of Set 12 | elko
# Processing Record 13 of Set 12 | barra do bugres
# Processing Record 14 of Set 12 | yeniseysk
# Processing Record 15 of Set 12 | nantucket
# Processing Record 16 of Set 12 | netishyn
# Processing Record 17 of Set 12 | bontang
# Processing Record 18 of Set 12 | vikarabad
# Processing Record 19 of Set 12 | vyazma
# Processing Record 20 of Set 12 | suchiate
# Processing Record 21 of Set 12 | talakan
# Processing Record 22 of Set 12 | washim
# Processing Record 23 of Set 12 | kargasok
# Processing Record 24 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 12 | naliya
# Processing Record 26 of Set 12 | manuk mangkaw
# Processing Record 27 of Set 12 | menemen
# Processing Record 28 of Set 12 | drovyanaya
# Processing Record 29 of Set 12 | buguruslan
# Processing Record 30 of Set 12 | poso
# Processing Record 31 of Set 12 | harper
# Processing Record 32 of Set 12 | mitchell
# Processing Record 33 of Set 12 | katherine
# Processing Record 34 of Set 12 | khovu-aksy
# Processing Record 35 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 12 | praia da vitoria
# Processing Record 37 of Set 12 | tanta
# Processing Record 38 of Set 12 | verdun
# Processing Record 39 of Set 12 | marawi
# Processing Record 40 of Set 12 | pitrufquen
# Processing Record 41 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 12 | upington
# Processing Record 43 of Set 12 | nisia floresta
# Processing Record 44 of Set 12 | menongue
# Processing Record 45 of Set 12 | machacamarca
# Processing Record 46 of Set 12 | kawalu
# Processing Record 47 of Set 12 | noshiro
# Processing Record 48 of Set 12 | yima
# Processing Record 49 of Set 12 | finschhafen
# Processing Record 50 of Set 12 | muros
# Processing Record 1 of Set 13 | znamensk
# Processing Record 2 of Set 13 | ryzdvyanyy
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | el dorado
# Processing Record 5 of Set 13 | sembakung
# Processing Record 6 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 13 | erzin
# Processing Record 8 of Set 13 | platteville
# Processing Record 9 of Set 13 | boyolangu
# Processing Record 10 of Set 13 | riyadh
# Processing Record 11 of Set 13 | norsup
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 577

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Iberia  29.9502  -91.7507     79.09        78         100       14.97
# 1       Hobart -42.8794  147.3294     56.26        62          75        4.61
# 2        Pevek  69.7008  170.3133    -14.13        98         100        3.94
# 3       Kodiak  57.7900 -152.4072     42.31        49         100        8.05
# 4        Vaini -21.2000 -175.2000     82.56        78          75        3.44
# 5       Atuona  -9.8000 -139.0333     79.36        71           2       22.62
# 6  Port Alfred -33.5906   26.8910     63.03        77           5       10.11
# 7   Bredasdorp -34.5322   20.0403     59.11        74           1       12.88
# 8  Jacqueville   5.2052   -4.4146     82.09        87          99       10.60
# 9        Airai  -8.9266  125.4092     63.19        82          68        2.15
#
#   Country          Current Description                 Date
# 0      US              overcast clouds  2022-04-05 23:09:12
# 1      AU                broken clouds  2022-04-05 23:08:04
# 2      RU              overcast clouds  2022-04-05 23:09:13
# 3      US              overcast clouds  2022-04-05 23:09:13
# 4      TO  light intensity shower rain  2022-04-05 23:05:25
# 5      PF                    clear sky  2022-04-05 23:09:13
# 6      ZA                    clear sky  2022-04-05 23:09:14
# 7      ZA                    clear sky  2022-04-05 23:09:14
# 8      CI              overcast clouds  2022-04-05 23:09:14
# 9      TL                broken clouds  2022-04-05 23:09:14

# %%
# Correct the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Iberia      US  29.9502  -91.7507     79.09        78         100
# 1       Hobart      AU -42.8794  147.3294     56.26        62          75
# 2        Pevek      RU  69.7008  170.3133    -14.13        98         100
# 3       Kodiak      US  57.7900 -152.4072     42.31        49         100
# 4        Vaini      TO -21.2000 -175.2000     82.56        78          75
# 5       Atuona      PF  -9.8000 -139.0333     79.36        71           2
# 6  Port Alfred      ZA -33.5906   26.8910     63.03        77           5
# 7   Bredasdorp      ZA -34.5322   20.0403     59.11        74           1
# 8  Jacqueville      CI   5.2052   -4.4146     82.09        87          99
# 9        Airai      TL  -8.9266  125.4092     63.19        82          68
#
#    Wind Speed          Current Description                 Date
# 0       14.97              overcast clouds  2022-04-05 23:09:12
# 1        4.61                broken clouds  2022-04-05 23:08:04
# 2        3.94              overcast clouds  2022-04-05 23:09:13
# 3        8.05              overcast clouds  2022-04-05 23:09:13
# 4        3.44  light intensity shower rain  2022-04-05 23:05:25
# 5       22.62                    clear sky  2022-04-05 23:09:13
# 6       10.11                    clear sky  2022-04-05 23:09:14
# 7       12.88                    clear sky  2022-04-05 23:09:14
# 8       10.60              overcast clouds  2022-04-05 23:09:14
# 9        2.15                broken clouds  2022-04-05 23:09:14

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
